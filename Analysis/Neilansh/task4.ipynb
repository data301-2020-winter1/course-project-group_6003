# %%
#import sys, os
#sys.path.insert(0, os.path.abspath('..'))
#from Scripts.project_functions import load_and_clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-97a5dc086091> in <module>
#       1 import sys, os
#       2 sys.path.insert(0, os.path.abspath('..'))
# ----> 3 from Scripts.project_functions import load_and_clean
#
# ~\desktop\Uni files\Term I\DATA 301\Project\course-project-group_6003\Analysis\Scripts\project_functions.py in <module>
#     243   {
#     244    "cell_type": "code",
# --> 245    "execution_count": null,
#     246    "metadata": {},
#     247    "outputs": [],
#
# NameError: name 'null' is not defined

# %%
#dataset_address = "file path to dataset"
#df = load_and_clean(dataset_address)   
#df
