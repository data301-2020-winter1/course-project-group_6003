# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv("C:\\Users\\Kris\\301\\Data\\Gamesales.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
dataset = 'C:\\Users\\Kris\\301\\Data\\Gamesales.csv'
df1 = pd.read_csv(dataset)              
df1.head(7)

df1 = ( pd.read_csv(dataset) 
         .dropna(how = "any")                      
         .rename(columns = {"Name" : "Game Title"})    
         .drop_duplicates()    
        )
df1.head(10)
# Out:
#                    Game Title Platform  Year_of_Release     Genre  \
# 0                  Wii Sports      Wii           2006.0    Sports
# 2              Mario Kart Wii      Wii           2008.0    Racing
# 3           Wii Sports Resort      Wii           2009.0    Sports
# 6       New Super Mario Bros.       DS           2006.0  Platform
# 7                    Wii Play      Wii           2006.0      Misc
# 8   New Super Mario Bros. Wii      Wii           2009.0  Platform
# 11              Mario Kart DS       DS           2005.0    Racing
# 13                    Wii Fit      Wii           2007.0    Sports
# 14         Kinect Adventures!     X360           2010.0      Misc
# 15               Wii Fit Plus      Wii           2009.0    Sports
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                 Nintendo     41.36     28.96      3.77         8.45
# 2                 Nintendo     15.68     12.76      3.79         3.29
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("C:\\Users\\Kris\\301\\Data\\Gamesales.csv")
df.head()
df.drop(['Year_of_Release', 'User_Count', 'User_Score', 'Critic_Count', 'Critic_Score', 'Developer', 'Rating'], axis=1, inplace = True)
df1 = df[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
df1.head(15)
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         Sports     41.36     28.96      3.77         8.45         82.53
# 1       Platform     29.08      3.58      6.81         0.77         40.24
# 2         Racing     15.68     12.76      3.79         3.29         35.52
# 3         Sports     15.61     10.93      3.28         2.95         32.77
# 4   Role-Playing     11.27      8.89     10.22         1.00         31.37
# 5         Puzzle     23.20      2.26      4.22         0.58         30.26
# 6       Platform     11.28      9.14      6.50         2.88         29.80
# 7           Misc     13.96      9.18      2.93         2.84         28.92
# 8       Platform     14.44      6.94      4.70         2.24         28.32
# 9        Shooter     26.93      0.63      0.28         0.47         28.31
# 10    Simulation      9.05     10.95      1.93         2.74         24.67
# 11        Racing      9.71      7.47      4.13         1.90         23.21
# ...

# %%
print(df.columns)
sns.countplot(y=df1['Genre'])
plt.title("Different Video Game Genres")
# Out:
# Index(['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales',
#        'Global_Sales'],
#       dtype='object')
# Text(0.5, 1.0, 'Different Video Game Genres')

# %%
sns.kdeplot(data=df1['Year_of_Release'])
plt.ylabel = 'Amount of Games Released Per Year'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv("C:\\Users\\Kris\\301\\Data\\Gamesales.csv")
df
df1 = df.rename(columns = {"Name": "Game Title"})
df1.dropna(how = 'any')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,20))
ax = sns.violinplot(x="Global_Sales", y="Genre", color = 'skyblue', data=df1)
